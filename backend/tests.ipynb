# %%
import pandas as pd

# %%
data = pd.read_csv("../backend/dataset/indian_water_physicochemical_parameters.csv", encoding = 'unicode_escape')
data = data.loc[:, ~data.columns.str.contains('^Unnamed')]
data
# Out:
#      STATION CODE                                         LOCATIONS  \
# 0          1393.0                     DAMANGANGA AT D/S OF MADHUBAN
# 1          1150.0          DAMANGANGA AT KACHIGAON U\S AT GIDC WIER
# 2          1865.0                           RIVER DHADAR AT KOTHADA
# 3          1149.0                              KOLAK AT PATALIA BDG
# 4          1399.0  ZUARI AT D/S OF PT. WHERE KUMBARJRIA CANAL JOINS
# ..            ...                                               ...
# 733        2052.0                           TUIRIAL UPPER CATCHMENT
# 734        2053.0                           TUIRIAL LOWER CATCHMENT
# 735        1403.0                GUMTI AT U/S SOUTH TRIPURA,TRIPURA
# 736        1404.0               GUMTI AT D/S SOUTH TRIPURA, TRIPURA
# 737        1726.0  CHANDRAPUR, AGARTALA D/S OF HAORA RIVER, TRIPURA
#
#            STATE  Temp  D.O. (mg/l)   PH  CONDUCTIVITY (Âµmhos/cm)  \
# 0    DAMAN & DIU  31.0          7.1  7.8                     151.0
# ...

# %%
temp = data["Temp"].values
print(type(temp[0]))
temp
# Out:
# <class 'numpy.float64'>
# array([31. , 28. , 27. , 29. , 31. , 30. , 30. , 29. , 29. , 29. , 28. ,
#        30. , 30. , 27. , 28. , 29. , 28. , 29. , 29. , 30. , 28. , 28. ,
#        29. , 28. , 30. , 30. , 31. , 29. , 30. , 29. , 29. , 29. , 29. ,
#        30. , 27. , 27. , 27. , 23. , 29. , 29. , 29. , 28. , 29. , 29. ,
#        29. , 29. , 30. , 30. , 29. , 25. , 30. , 30. , 31. , 30. , 30. ,
#        28. , 28. , 28. , 27. , 27. , 26. , 27. , 28. , 23. , 22. , 23. ,
#        26. , 26. , 26. , 26. , 26. , 26. , 29. , 28. , 28. , 29. , 26. ,
#        26. , 28. , 29. , 26. , 26. , 25. , 29. , 29. , 25. , 27. , 27. ,
#        29. , 29. , 29. , 27. , 30. , 27. , 27. , 25. , 25. , 26. , 29. ,
#        27. , 27. , 27. , 28. , 26. , 29. , 27. , 28. , 29. , 28. , 29. ,
#        26. , 28. , 28. , 28. , 28. , 27. , 28. , 28. , 28. , 28. , 28. ,
#        28. , 26. , 28. , 29. , 28. , 26. , 29. , 29. , 27. , 29. , 27. ,
# ...

# %%
dates = data["date"].values
print(type(dates[0]))
dates
# Out:
# <class 'str'>
# array(['2012-01-01', '2012-01-04', '2012-01-05', '2012-01-06',
#        '2012-01-07', '2012-01-10', '2012-01-13', '2012-01-15',
#        '2012-01-16', '2012-01-17', '2012-01-18', '2012-01-20',
#        '2012-01-22', '2012-01-23', '2012-01-26', '2012-01-27',
#        '2012-01-28', '2012-02-02', '2012-02-04', '2012-02-05',
#        '2012-02-06', '2012-02-10', '2012-02-11', '2012-02-12',
#        '2012-02-13', '2012-02-15', '2012-02-16', '2012-02-18',
#        '2012-02-19', '2012-02-20', '2012-02-21', '2012-02-22',
#        '2012-02-24', '2012-02-25', '2012-02-27', '2012-03-01',
#        '2012-03-02', '2012-03-03', '2012-03-04', '2012-03-05',
#        '2012-03-06', '2012-03-07', '2012-03-08', '2012-03-09',
#        '2012-03-10', '2012-03-11', '2012-03-12', '2012-03-14',
#        '2012-03-16', '2012-03-17', '2012-03-18', '2012-03-19',
#        '2012-03-20', '2012-03-22', '2012-03-23', '2012-03-24',
#        '2012-03-26', '2012-03-27', '2012-03-28', '2012-04-01',
# ...

# %%
dict_ = dict(zip(dates, data["Temp"].values))

# %%
dict_
# Out:
# {'2012-01-01': 31.0,
#  '2012-01-04': 28.0,
#  '2012-01-05': 27.0,
#  '2012-01-06': 29.0,
#  '2012-01-07': 31.0,
#  '2012-01-10': 30.0,
#  '2012-01-13': 30.0,
#  '2012-01-15': 29.0,
#  '2012-01-16': 29.0,
#  '2012-01-17': 29.0,
#  '2012-01-18': 28.0,
#  '2012-01-20': 30.0,
#  '2012-01-22': 30.0,
#  '2012-01-23': 27.0,
#  '2012-01-26': 28.0,
#  '2012-01-27': 29.0,
#  '2012-01-28': 28.0,
#  '2012-02-02': 29.0,
#  '2012-02-04': 29.0,
#  '2012-02-05': 30.0,
#  '2012-02-06': 28.0,
#  '2012-02-10': 28.0,
#  '2012-02-11': 29.0,
#  '2012-02-12': 28.0,
#  '2012-02-13': 30.0,
#  '2012-02-15': 30.0,
#  '2012-02-16': 31.0,
#  '2012-02-18': 29.0,
#  '2012-02-19': 30.0,
#  '2012-02-20': 29.0,
#  '2012-02-21': 29.0,
#  '2012-02-22': 29.0,
#  '2012-02-24': 29.0,
#  '2012-02-25': 30.0,
#  '2012-02-27': 27.0,
#  '2012-03-01': 27.0,
#  '2012-03-02': 27.0,
#  '2012-03-03': 23.0,
#  '2012-03-04': 29.0,
#  '2012-03-05': 29.0,
#  '2012-03-06': 29.0,
#  '2012-03-07': 28.0,
#  '2012-03-08': 29.0,
# ...
